# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
h = 0.01
x = np.arange(-20, 20, h)

def f(x):
    return np.exp(-(x**2))

def derivada(x, h):
    return (f(x+h)-f(x-h))/(2*h)
yp = derivada(x, h)

plt.plot(x, yp, label = "Derivada e^{(-x^2)}")
plt.legend()
